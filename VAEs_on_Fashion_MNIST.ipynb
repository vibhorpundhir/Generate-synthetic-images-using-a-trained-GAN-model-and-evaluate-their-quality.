# %% [markdown]
# # Variational Autoencoders
#
# Variational Autoencoders (VAEs) are a type of generative model that learn to encode input data into a compressed representation and then decode it back while ensuring the generated outputs are meaningful and diverse. They are widely used for tasks like image generation, anomaly detection, and data compression.
#
# ## How VAEs works
#
# VAEs consist of two main components:
#
# - **Encoder** – Maps input data x to a latent space z (a lower-dimensional representation). Instead of a fixed encoding, it learns a probability distribution over the latent space.
# <br>
# - **Decoder** – Takes a sample from the latent distribution and reconstructs the original data x ′.
# <br>
# <br>
# Unlike traditional Autoencoders, which directly map input to a fixed latent vector, VAEs introduce probabilistic encoding using a mean 𝜇 and variance σ^2, enforcing continuity in the latent space.

# %% [markdown]
# ## Dataset Description
#
# The Fashion MNIST contains grayscale images of size 28x28 like t-shirts, dresses, sneakers and bags.
#
# - **Total Images**: 70,000 (60,000 training + 10,000 test)
# <br>
# - **Number of Classes**: 10 (Different fashion categories)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from PIL import Image

# %% [markdown]
# ## Preprocessing Steps
#
# - The dataset is loaded using `tf.keras.datasets.fashion_mnist.load_data()` and is splitted into training and testing sets along with its respective labels.
#
# - The pixel value range from 0 to 255, so it is normalized to range 0 to 1 by dividing it by 255.
#
# - CNNs takes input as 4D tensors (batch_size, height, witdth, channels) so we expand the dimension to include channels i.e 1 in this case.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Normalize the pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Expand dimensions to add a channel axis (28x28 -> 28x28x1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
latent_dim = 8
learning_rate = 1e-4
batch_size = 32 # Number of samples per batch during training
epochs = 50

# %% [markdown]
# ## Encoder architecture
#
# **Input Layer :**
# <br>
# - Takes input images of size 28x28x1
#
#
# **First Convolution Layer :**
# <br>
# - We have 32 filters in the first convolution layer with kernel size of 3 and activation function **Relu** with stride downsampling of 2.
#
# **Second Convolution Layer :**
# <br>
# - The second convolutional layer increases filters to 64, maintaining the 3×3 kernel, ReLU activation, stride of 2, and same padding, reducing the size to (7, 7, 64)
#
# **Third Convolution Layer :**
# - The third convolutional layer further expands to 128 filters, again using a 3×3 kernel, ReLU activation, stride of 2, and same padding, resulting in (4, 4, 128).
#
# **Fourth convolution Layer :**
# - The fourth convolutional layer reaches 256 filters, with the same parameters, compressing the output to (2, 2, 256) and then Batch Noramlization is applied to stabilize training followed by Dropout layer to prevent overfitting.
#
# **Flattened Layer :**
# - The output is then flattened into a 1D vector (1024 units), which is passed through a dense layer of 16 neurons with ReLU activation.
#
# **Dense Layer :**
# - The latent space representation is defined using two separate dense layers: z_mean, which represents the center of the latent space, and z_log_var, which captures its variance.
#
# **Sampling Layer :**
# - Finally, a sampling layer applies the reparameterization trick, generating z by adding a small random noise (epsilon) to allow smooth backpropagation, producing the final latent vector.

# %%
encoder_inputs = tf.keras.Input(shape=(28, 28, 1))
# Convolutional layers to extract features while progressively reducing spatial dimensions
x = tf.keras.layers.Conv2D(32, 3, activation='relu', strides=2, padding='same')(encoder_inputs)
x = tf.keras.layers.Conv2D(64, 3, activation='relu', strides=2, padding='same')(x)  # Downsamples to 7x7
x = tf.keras.layers.Conv2D(128, 3, activation='relu', strides=2, padding='same')(x) # Downsamples to 4x4
x = tf.keras.layers.Conv2D(256, 3, activation='relu', strides=2, padding='same')(x) # Downsamples to 2x2
# Batch Normalization to stabilize training and improve convergence
x = tf.keras.layers.BatchNormalization()(x)

# Dropout to prevent overfitting (randomly drops 30% of connections)
x = tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(16, activation='relu')(x)

# Define the mean and log variance layers for the latent space representation
z_mean = tf.keras.layers.Dense(latent_dim, name='z_mean')(x)
z_log_var = tf.keras.layers.Dense(latent_dim, name='z_log_var')(x)


# Reparameterization Trick: Sample a point from the latent space distribution
def sampling(args):
    z_mean, z_log_var = args
    batch = tf.shape(z_mean)[0]
    dim = tf.shape(z_mean)[1]
    epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Lambda layer to apply the reparameterization trick
z = tf.keras.layers.Lambda(sampling, name='z')([z_mean, z_log_var])
# Define the encoder model with inputs and outputs (z_mean, z_log_var, and sampled z)
encoder = tf.keras.Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')

# %% [markdown]
# ## Decoder architecture
#
# **Input Layer :**
#
# - The latent input layer takes a latent vector of size (latent_dim,), which represents the compressed feature space.
#
# **Dense Layer :**
#
# - This vector is first passed through a dense layer with 7 × 7 × 256 neurons and ReLU activation.
#
# **Reshape Layer :**
#
# - The reshape layer then converts this 1D vector into a (7, 7, 256) tensor, effectively preparing it for upsampling.
#
# **First Transposed Convolution Layer :**
#
# - The first transposed convolutional layer applies 128 filters with a 3×3 kernel, ReLU activation, stride of 2, and same padding, upsampling the feature map to (14, 14, 128).
#
# **Second Transposed Convolution Layer :**
#
# - This uses 64 filters with same kernel size, activation function and strides and therfore upsamples the image to (28, 28, 64).
#
# **Third Transposed Convolution Layer :**
#
# - The third transposed convolutional layer has 32 filters with a 3×3 kernel and ReLU activation, but without striding, keeping the spatial size (28, 28, 32).
#
# **Output Layer :**
#
# -  The output layer uses a single filter with a 3×3 kernel, sigmoid activation, and same padding, producing a (28, 28, 1) grayscale image where each pixel value is normalized between 0 and 1.

# %%
# Define the decoder input, which takes a latent vector of size `latent_dim`
latent_inputs = tf.keras.Input(shape=(latent_dim,))
x = tf.keras.layers.Dense(7 * 7 * 256, activation='relu')(latent_inputs)
x = tf.keras.layers.Reshape((7, 7, 256))(x)
# Transposed convolution layers (upsampling layers) to progressively reconstruct the image
x = tf.keras.layers.Conv2DTranspose(128, 3, activation='relu', strides=2, padding='same')(x)
x = tf.keras.layers.Conv2DTranspose(64, 3, activation='relu', strides=2, padding='same')(x)
x = tf.keras.layers.Conv2DTranspose(32, 3, activation='relu', padding='same')(x)
decoder_outputs = tf.keras.layers.Conv2DTranspose(1, 3, activation='sigmoid', padding='same')(x)

decoder = tf.keras.Model(latent_inputs, decoder_outputs, name='decoder')

# %% [markdown]
# ## Training Steps
#
# - Initialize VAE by taking encoder and decoder as input.
# - Define three losses i.e total loss (reconstruction loss + KL loss), reconstruction loss (Tracks how well the decoder reconstructs the original input), KL divergence (ensures a well-formed latent space).
# - Returns a list of metrics that are updated during training, helping to monitor model performance.
# - Extracts inputs from the dataset (ignoring labels _ since VAEs are unsupervised).
# - Passes input through the encoder, obtaining:
# z_mean: The mean of the latent distribution.
# z_log_var: The logarithm of the variance of the latent distribution.
# z: The sampled latent vector using the reparameterization trick.
# - Passes z through the decoder to reconstruct the input.
# - Uses binary cross-entropy loss between the original input and the reconstructed output. Summed across pixels to measure overall reconstruction accuracy. Averaged across the batch to get the final reconstruction loss.
# - The KL divergence loss ensures the latent space follows a Gaussian distribution.
# - Updates the loss metrics to track training performance.
# - Returns the latest loss values as a dictionary for logging.

# %% [markdown]
# ## Testing Steps
#
# - Similar to train_step, but no gradient calculation is needed.
# - Computes reconstruction loss and KL loss exactly like in train_step.
# - Returns a dictionary containing test loss values.

# %%
# Define the Variational Autoencoder (VAE) model
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder # Encoder model
        self.decoder = decoder # Decoder model
        # Trackers for different loss components
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    # Property to return the tracked loss metrics
    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        inputs, _ = data
        with tf.GradientTape() as tape:
          # Pass the input through the encoder to obtain latent representations
            z_mean, z_log_var, z = self.encoder(inputs)
             # Pass the sampled latent vector through the decoder to reconstruct the image
            reconstruction = self.decoder(z)
            # Compute the reconstruction loss using binary cross-entropy
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(inputs, reconstruction),
                    axis=(1, 2)  # Sum over width and height dimensions
                )
            )
            # Compute the KL divergence loss (regularization term)
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            # Total loss = Reconstruction Loss + KL Divergence Loss
            total_loss = reconstruction_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {m.name: m.result() for m in self.metrics}


    # Custom validation/testing step
    def test_step(self, data):
        inputs, _ = data
        # Encode the input to obtain latent representations
        z_mean, z_log_var, z = self.encoder(inputs)
        # Decode the latent vector to reconstruct the image
        reconstruction = self.decoder(z)
        # Compute the reconstruction loss
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                tf.keras.losses.binary_crossentropy(inputs, reconstruction),
                axis=(1, 2)
            )
        )
        # Compute the KL divergence loss
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = reconstruction_loss + kl_loss
        # Return losses for evaluation
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# %% [markdown]
# - Creates an instance of the VAE class, using the previously defined encoder and decoder models.
# - This VAE model will be trained to learn an efficient latent space representation and reconstruct input images.
# - Implements an exponential decay learning rate:
# <br>
# **initial_learning_rate=1e-3:** Starts training with a learning rate of 0.001.
# <br>
# **decay_steps=10000:** The learning rate is updated after every 10,000 steps.
# <br>
# **decay_rate=0.96:** After every 10,000 steps, the learning rate is multiplied by 0.96, gradually reducing it.
# <br>
# **staircase=True:** Learning rate decreases in discrete steps, rather than smoothly.

# %%
# Create an instance of the VAE model using the encoder and decoder
vae = VAE(encoder, decoder)

# Define an exponential learning rate decay schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True
)
vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
history = vae.fit(x_train, x_train,
                 epochs=epochs,
                 batch_size=batch_size,
                 validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - kl_loss: 9.3990 - reconstruction_loss: 336.0690 - total_loss: 345.4681 - val_kl_loss: 13.3339 - val_loss: 242.9937 - val_reconstruction_loss: 229.6598
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 12.9594 - reconstruction_loss: 242.7678 - total_loss: 255.7271 - val_kl_loss: 13.4433 - val_loss: 237.6922 - val_reconstruction_loss: 224.2490
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 12.7888 - reconstruction_loss: 238.8614 - total_loss: 251.6503 - val_kl_loss: 12.9313 - val_loss: 236.7428 - val_reconstruction_loss: 223.8115
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 12.6889 - reconstruction_loss: 236.0823 - total_loss: 248.7712 - val_kl_loss: 12.9044 - val_loss: 234.0240 - val_reconstruction_loss: 221.1196
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 12.7933 - reconstruction_loss: 234.1418 - total_loss: 246.9351 - val_kl_loss: 13.0187 - val_loss: 233.0351 - val_reconstruction_loss: 220.0164
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 12.8741 - reconstruction_loss: 232.8022 - total_loss: 245.6764 - val_kl_loss: 12.9008 - val_loss: 232.0364 - val_reconstruction_loss: 219.1356
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 12.8365 - reconstruction_loss: 231.5562 - total_loss: 244.3927 - val_kl_loss: 12.8092 - val_loss: 232.7730 - val_reconstruction_loss: 219.9638
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - kl_loss: 12.8153 - reconstruction_loss: 231.0152 - total_loss: 243.8308 - val_kl_loss: 12.9516 - val_loss: 230.1693 - val_reconstruction_loss: 217.2176
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 12.8744 - reconstruction_loss: 229.5264 - total_loss: 242.4008 - val_kl_loss: 12.7601 - val_loss: 232.3195 - val_reconstruction_loss: 219.5594
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 12.9235 - reconstruction_loss: 228.9852 - total_loss: 241.9089 - val_kl_loss: 12.9979 - val_loss: 229.9415 - val_reconstruction_loss: 216.9436
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.0504 - reconstruction_loss: 228.2186 - total_loss: 241.2692 - val_kl_loss: 12.8204 - val_loss: 228.6469 - val_reconstruction_loss: 215.8265
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.1039 - reconstruction_loss: 227.5272 - total_loss: 240.6309 - val_kl_loss: 12.9319 - val_loss: 226.0141 - val_reconstruction_loss: 213.0822
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.2192 - reconstruction_loss: 227.0106 - total_loss: 240.2298 - val_kl_loss: 13.0461 - val_loss: 226.9624 - val_reconstruction_loss: 213.9163
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.2323 - reconstruction_loss: 226.5052 - total_loss: 239.7375 - val_kl_loss: 13.0997 - val_loss: 228.3046 - val_reconstruction_loss: 215.2049
# Epoch 15/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.2820 - reconstruction_loss: 225.7165 - total_loss: 238.9984 - val_kl_loss: 13.3882 - val_loss: 225.3823 - val_reconstruction_loss: 211.9941
# Epoch 16/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - kl_loss: 13.3366 - reconstruction_loss: 225.1880 - total_loss: 238.5246 - val_kl_loss: 13.1678 - val_loss: 225.8190 - val_reconstruction_loss: 212.6511
# Epoch 17/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.3644 - reconstruction_loss: 225.8230 - total_loss: 239.1874 - val_kl_loss: 13.4164 - val_loss: 226.2531 - val_reconstruction_loss: 212.8367
# Epoch 18/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.3743 - reconstruction_loss: 224.9937 - total_loss: 238.3680 - val_kl_loss: 13.5578 - val_loss: 226.7463 - val_reconstruction_loss: 213.1885
# Epoch 19/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.4125 - reconstruction_loss: 224.4894 - total_loss: 237.9019 - val_kl_loss: 13.4290 - val_loss: 226.9198 - val_reconstruction_loss: 213.4908
# Epoch 20/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.4702 - reconstruction_loss: 224.2609 - total_loss: 237.7310 - val_kl_loss: 13.3792 - val_loss: 226.6224 - val_reconstruction_loss: 213.2432
# Epoch 21/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.4791 - reconstruction_loss: 224.0216 - total_loss: 237.5007 - val_kl_loss: 13.5560 - val_loss: 226.6672 - val_reconstruction_loss: 213.1112
# Epoch 22/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.4884 - reconstruction_loss: 223.2316 - total_loss: 236.7200 - val_kl_loss: 13.4756 - val_loss: 225.5287 - val_reconstruction_loss: 212.0530
# Epoch 23/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - kl_loss: 13.5027 - reconstruction_loss: 223.5279 - total_loss: 237.0306 - val_kl_loss: 13.6136 - val_loss: 224.6314 - val_reconstruction_loss: 211.0179
# Epoch 24/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.5398 - reconstruction_loss: 223.0129 - total_loss: 236.5529 - val_kl_loss: 13.5803 - val_loss: 224.3767 - val_reconstruction_loss: 210.7964
# Epoch 25/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.5377 - reconstruction_loss: 222.8892 - total_loss: 236.4267 - val_kl_loss: 13.4951 - val_loss: 225.3543 - val_reconstruction_loss: 211.8592
# Epoch 26/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.5657 - reconstruction_loss: 222.9754 - total_loss: 236.5411 - val_kl_loss: 13.5804 - val_loss: 225.9066 - val_reconstruction_loss: 212.3262
# Epoch 27/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.6153 - reconstruction_loss: 222.9739 - total_loss: 236.5892 - val_kl_loss: 13.4014 - val_loss: 225.0818 - val_reconstruction_loss: 211.6804
# Epoch 28/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.5891 - reconstruction_loss: 222.4943 - total_loss: 236.0833 - val_kl_loss: 13.7988 - val_loss: 225.7978 - val_reconstruction_loss: 211.9990
# Epoch 29/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - kl_loss: 13.6147 - reconstruction_loss: 222.0767 - total_loss: 235.6914 - val_kl_loss: 13.6590 - val_loss: 227.6667 - val_reconstruction_loss: 214.0078
# Epoch 30/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.6595 - reconstruction_loss: 222.8195 - total_loss: 236.4789 - val_kl_loss: 13.5939 - val_loss: 224.1303 - val_reconstruction_loss: 210.5365
# Epoch 31/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.6481 - reconstruction_loss: 222.5558 - total_loss: 236.2041 - val_kl_loss: 13.6568 - val_loss: 224.2311 - val_reconstruction_loss: 210.5743
# Epoch 32/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.6678 - reconstruction_loss: 222.3359 - total_loss: 236.0037 - val_kl_loss: 13.3444 - val_loss: 226.0713 - val_reconstruction_loss: 212.7269
# Epoch 33/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.6511 - reconstruction_loss: 222.1465 - total_loss: 235.7976 - val_kl_loss: 13.5585 - val_loss: 224.6145 - val_reconstruction_loss: 211.0561
# Epoch 34/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.6927 - reconstruction_loss: 222.4301 - total_loss: 236.1229 - val_kl_loss: 13.6173 - val_loss: 225.5238 - val_reconstruction_loss: 211.9065
# Epoch 35/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.6943 - reconstruction_loss: 221.8150 - total_loss: 235.5095 - val_kl_loss: 13.4847 - val_loss: 223.7053 - val_reconstruction_loss: 210.2206
# Epoch 36/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.6977 - reconstruction_loss: 221.9570 - total_loss: 235.6545 - val_kl_loss: 13.5536 - val_loss: 224.1734 - val_reconstruction_loss: 210.6198
# Epoch 37/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.6991 - reconstruction_loss: 222.0160 - total_loss: 235.7150 - val_kl_loss: 13.4579 - val_loss: 225.5145 - val_reconstruction_loss: 212.0565
# Epoch 38/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.6687 - reconstruction_loss: 221.3343 - total_loss: 235.0032 - val_kl_loss: 13.6312 - val_loss: 224.8584 - val_reconstruction_loss: 211.2272
# Epoch 39/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.7375 - reconstruction_loss: 221.5197 - total_loss: 235.2572 - val_kl_loss: 13.4933 - val_loss: 225.4759 - val_reconstruction_loss: 211.9825
# Epoch 40/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.7243 - reconstruction_loss: 221.1886 - total_loss: 234.9128 - val_kl_loss: 13.5851 - val_loss: 225.3000 - val_reconstruction_loss: 211.7149
# Epoch 41/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.7475 - reconstruction_loss: 221.3483 - total_loss: 235.0957 - val_kl_loss: 13.6186 - val_loss: 224.5044 - val_reconstruction_loss: 210.8857
# Epoch 42/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.7493 - reconstruction_loss: 221.7046 - total_loss: 235.4541 - val_kl_loss: 13.8160 - val_loss: 224.0620 - val_reconstruction_loss: 210.2459
# Epoch 43/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.7534 - reconstruction_loss: 220.9847 - total_loss: 234.7381 - val_kl_loss: 13.7496 - val_loss: 225.5181 - val_reconstruction_loss: 211.7685
# Epoch 44/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.7726 - reconstruction_loss: 221.5117 - total_loss: 235.2843 - val_kl_loss: 13.5558 - val_loss: 225.6962 - val_reconstruction_loss: 212.1403
# Epoch 45/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.7679 - reconstruction_loss: 221.0299 - total_loss: 234.7977 - val_kl_loss: 13.6923 - val_loss: 223.9121 - val_reconstruction_loss: 210.2198
# Epoch 46/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.8018 - reconstruction_loss: 221.2338 - total_loss: 235.0358 - val_kl_loss: 13.4882 - val_loss: 225.7098 - val_reconstruction_loss: 212.2216
# Epoch 47/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.8064 - reconstruction_loss: 221.1456 - total_loss: 234.9518 - val_kl_loss: 13.7424 - val_loss: 223.4274 - val_reconstruction_loss: 209.6850
# Epoch 48/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - kl_loss: 13.8305 - reconstruction_loss: 221.2708 - total_loss: 235.1014 - val_kl_loss: 13.4923 - val_loss: 222.7469 - val_reconstruction_loss: 209.2546
# Epoch 49/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - kl_loss: 13.7780 - reconstruction_loss: 220.6078 - total_loss: 234.3859 - val_kl_loss: 13.9444 - val_loss: 223.8738 - val_reconstruction_loss: 209.9294
# Epoch 50/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - kl_loss: 13.7930 - reconstruction_loss: 221.1493 - total_loss: 234.9423 - val_kl_loss: 13.7096 - val_loss: 223.0921 - val_reconstruction_loss: 209.3824

# %%
plt.plot(history.history['kl_loss'], label='Training Loss')
plt.plot(history.history['val_kl_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# - It selects 10 test images, displays them in the first row.
# - Generates reconstructed versions using the encoder and decoder, displaying them in the second row.
# - The encoder extracts a compressed representation (latent space), and the decoder reconstructs the image from this representation.

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].squeeze(), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    z_mean, z_log_var, _ = encoder.predict(x_test[i][np.newaxis, ...])
    reconstruction = decoder.predict(z_mean)
    plt.imshow(reconstruction[0].squeeze(), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %% [markdown]
# - The encoder processes the test images (x_test) and outputs their latent space representations (z_mean).
# - **pca = PCA(n_components=2):** Initializes PCA to reduce the latent space to 2 dimensions.
# - **z_pca = pca.fit_transform(z_mean):** Transforms the latent representations (z_mean) into a 2D space for visualization.
# - Plots each data point using PCA-transformed latent space coordinates.
# - Colors correspond to the original class labels (y_test), using the 'tab10' colormap for better distinction.

# %%
# Encode the test dataset to obtain the latent representations (z_mean)
z_mean, _, _ = encoder.predict(x_test, batch_size=batch_size)
# Apply Principal Component Analysis (PCA) to reduce latent dimensions to 2D for visualization
pca = PCA(n_components=2)
z_pca = pca.fit_transform(z_mean)
# Plot the latent space in 2D
plt.figure(figsize=(12, 10))
plt.scatter(z_pca[:, 0], z_pca[:, 1], c=y_test, cmap='tab10')
plt.colorbar()
plt.title('Latent Space PCA')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %% [markdown]
# - n = 10: Specifies that 10 images will be generated and displayed.
# - Samples a random point from a Gaussian distribution in the latent space.
# - Passes the sampled latent vector to the decoder to generate an image.
# - Displays the generated grayscale image.

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    # Sample a random latent vector from a normal distribution
    z_sample = np.random.normal(size=(1, latent_dim))
    # Generate an image from the latent vector using the decoder
    generated = decoder.predict(z_sample)
    plt.imshow(generated[0].squeeze(), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
